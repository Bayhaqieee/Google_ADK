# %% [markdown]
# ## Environment Check

# %%
# Core imports for Google ADK
import os
from google.adk.agents import Agent

# Check environment configuration
print("Checking Google ADK Environment...")

# Option 1: Local LLM (Ollama + Llama3.1)
print("\n Option 1: Local LLM (Ollama)")
try:
    import requests
    response = requests.get("http://localhost:11434/api/tags", timeout=5)
    if response.status_code == 200:
        models = response.json().get('models', [])
        llama_models = [m['name'] for m in models if 'llama' in m['name'].lower()]
        if llama_models:
            print(f" Ollama running with Llama models: {llama_models}")
            ollama_available = True
            recommended_model = llama_models[0]  # Use first available
        else:
            print(" Ollama running but no Llama models found")
            print(" Install: ollama pull llama3.1")
            ollama_available = False
    else:
        print(" Ollama not responding")
        ollama_available = False
except:
    print(" Ollama not found")
    print(" Install: https://ollama.ai/download")
    ollama_available = False

# Option 2: Microsoft Azure
print("\n Option 2: Microsoft Azure")
azure_openai_api_key = os.getenv('AZURE_OPENAI_API_KEY')
if azure_openai_api_key:
    print(" Azure API key found")
    azure_available = True
else:
    print(" azure_openai_API_KEY not found")
    print(" Set: export azure_openai_API_KEY='your-key'")
    azure_available = False

# Show recommendations
print("\n Recommendations:")
if ollama_available:
    print(" Start with Ollama - perfect for learning!")
if azure_available:
    print(" Upgrade to Microsoft Azure for production features")
if not (ollama_available or azure_available):
    print(" Set up at least one option to continue")
# Out:
# Checking Google ADK Environment...
#
#  Option 1: Local LLM (Ollama)
#  Ollama running with Llama models: ['llama3.1:8b']
#
#  Option 2: Microsoft Azure
#  Azure API key found
#
#  Recommendations:
#  Start with Ollama - perfect for learning!
#  Upgrade to Microsoft Azure for production features

# %% [markdown]
# ## Development using Azure

# %%
import asyncio
from openai import AsyncAzureOpenAI

# 1. Initialize Azure client
client = AsyncAzureOpenAI(
    azure_endpoint = os.getenv('AZURE_OPENAI_ENDPOINT'),
    api_version = os.getenv('AZURE_OPENAI_API_VERSION'),
    api_key = os.getenv('AZURE_OPENAI_API_KEY'),
)

# Agent setup
agent_name = "Azure Agent"
deployment_name = "gpt-4o"  # Azure deployment name
instruction = """
You are a sophisticated AI assistant deployed via Azure OpenAI.
You have advanced reasoning capabilities and provide professional, insightful responses.
"""

print("Creating Azure Agent...")
print("Agent Created")
print(f"Name: {agent_name}")
print("Capabilities: High accuracy, scalable, enterprise-ready")

# Async function to query the model
async def ask_azure_agent(question: str):
    try:
        response = await client.chat.completions.create(
            model=deployment_name,  # Azure deployment name
            messages=[
                {"role": "system", "content": instruction},
                {"role": "user", "content": question}
            ],
            temperature=0.7
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {e}"

# Main test
async def main():
    print("Azure Runtime Ready")

    # TEST 1
    print("\nTEST 1: Advanced Reasoning")
    print("=" * 45)
    q1 = "Explain how AI agents could transform enterprise customer service, including 3 specific use cases and potential ROI."
    print(f"Question: {q1}")
    print("Azure model processing...")
    r1 = await ask_azure_agent(q1)
    print(f"Response: {r1}")

    # TEST 2
    print("\nTEST 2: Technical Knowledge")
    print("=" * 45)
    q2 = "Compare Azure AI solutions to LangChain and explain why enterprises choose Azure for production systems."
    print(f"Question: {q2}")
    print("Azure model processing...")
    r2 = await ask_azure_agent(q2)
    print(f"Response: {r2}")

    print("\nAzure Agent demonstration completed.")
    print("Suitable for reasoning, technical explanation, and enterprise applications.")

# Run it
await main()
# Out:
# Creating Azure Agent...
# Agent Created
# Name: Azure Agent
# Capabilities: High accuracy, scalable, enterprise-ready
# Azure Runtime Ready
#
# TEST 1: Advanced Reasoning
# =============================================
# Question: Explain how AI agents could transform enterprise customer service, including 3 specific use cases and potential ROI.
# Azure model processing...
# Response: AI agents have the potential to revolutionize enterprise customer service by improving efficiency, reducing operational costs, and enhancing the customer experience. By leveraging natural language processing (NLP), machine learning, and other AI capabilities, businesses can automate repetitive tasks, provide faster resolutions, and deliver personalized support at scale. Below are three specific use cases and their associated potential return on investment (ROI).
#
# ---
#
# ### **1. Automating Routine Inquiries with AI Chatbots**
# **Use Case:** Deploy AI-powered chatbots to handle common customer inquiries such as order tracking, account updates, FAQs, and troubleshooting basic issues. These chatbots can be available 24/7, providing consistent and immediate responses.
#
# **Benefits:**
# - **Cost Savings:** Reduces the need for human agents to answer repetitive questions, lowering labor costs.
# - **Scalability:** Handles multiple customer interactions simultaneously without requiring additional resources.
# - **Customer Satisfaction:** Improves response times, leading to higher customer satisfaction scores (CSAT).
#
# **Potential ROI:** Enterprises can reduce operational costs by 30-50% for routine inquiries. For example, a company handling 1 million customer queries annually could save $1M+ by automating 70% of these interactions with AI.
#
# ---
#
# ### **2. Intelligent Ticket Routing and Prioritization**
# **Use Case:** Utilize AI to classify and prioritize customer service tickets based on urgency, sentiment analysis, and issue type. The AI system can route tickets to the most appropriate agent or department, ensuring faster resolution times.
#
# **Benefits:**
# - **Efficiency Gains:** Reduces the time it takes for agents to manually classify and assign tickets.
# - **Improved Resolution Times:** Ensures that critical issues are addressed promptly, enhancing the overall customer experience.
# - **Agent Productivity:** Allows agents to focus on high-value tasks rather than administrative work.
#
# **Potential ROI:** By reducing ticket resolution times by 20-30%, businesses can increase agent productivity by 15-20% and retain more customers with faster issue resolution. For an enterprise with $10M in annual revenue, improving customer retention by just 5% through faster resolutions could result in incremental revenue gains of $500K.
#
# ---
#
# ### **3. Personalized Customer Support with AI-Driven Insights**
# **Use Case:** AI agents analyze customer data, interaction history, and preferences to offer personalized recommendations or solutions during live support interactions. This can include upselling, cross-selling, or tailoring responses to meet specific customer needs.
#
# **Benefits:**
# - **Enhanced Customer Experience:** Customers feel valued when their interactions are tailored to their preferences.
# - **Increased Revenue:** Personalized recommendations can drive upselling and cross-selling opportunities.
# - **Reduced Churn:** Satisfied customers are more likely to remain loyal to the brand.
#
# **Potential ROI:** Personalization can increase revenue per customer by 10-15%. For example, if an enterprise has 500,000 customers and each customer generates $100 annually, a 10% revenue lift would result in an additional $5M annually.
#
# ---
#
# ### **Conclusion:**
# AI agents enable enterprises to optimize customer service operations, improve customer satisfaction, and drive revenue growth. By automating routine inquiries, streamlining ticket management, and delivering personalized support, businesses can achieve significant ROI while scaling their customer service efforts. These transformations not only reduce costs but also create a competitive advantage, positioning organizations as leaders in customer experience.
#
# TEST 2: Technical Knowledge
# =============================================
# Question: Compare Azure AI solutions to LangChain and explain why enterprises choose Azure for production systems.
# Azure model processing...
# Response: Azure AI solutions and LangChain both provide powerful tools for building AI-driven applications, but they cater to different aspects of the AI and ML ecosystem. Enterprises often choose Azure for production systems due to its scalability, security, and integration capabilities. Here's a detailed comparison and explanation:
#
# ### **Azure AI Solutions**
# Azure AI solutions encompass a wide array of services and tools, including Azure OpenAI Service (GPT models), Azure Cognitive Services, Azure Machine Learning, and more. These solutions are designed for enterprises to build, deploy, and manage AI applications at scale. Key features include:
#
# 1. **Scalability and Reliability**:
#    - Azure provides enterprise-grade infrastructure, ensuring high availability and reliability for production systems.
#    - It supports global scale with a vast network of data centers, allowing businesses to deploy AI solutions closer to their customers.
#
# 2. **Security and Compliance**:
#    - Azure is trusted by enterprises due to its robust security features, including encryption, identity management, and network security.
#    - It offers compliance with major industry standards (e.g., GDPR, ISO, HIPAA), making it suitable for industries like healthcare, finance, and government.
#
# 3. **Integration with Enterprise Tools**:
#    - Azure AI integrates seamlessly with Microsoft products like Power BI, Microsoft 365, and Dynamics 365, enabling businesses to leverage AI across their existing workflows.
#    - It supports integration with other Azure services like Azure Data Factory, Azure Synapse Analytics, and Azure Kubernetes Service (AKS) for end-to-end AI pipelines.
#
# 4. **Managed Services**:
#    - Azure AI solutions are fully managed, reducing the complexity of infrastructure setup and maintenance.
#    - Enterprises can focus on building their applications without worrying about operational overhead.
#
# 5. **Customizability**:
#    - Azure Machine Learning allows enterprises to train and deploy custom models tailored to their specific needs.
#    - Azure OpenAI Service provides fine-tuning capabilities for OpenAI models like GPT, enabling personalized AI solutions.
#
# ### **LangChain**
# LangChain is a developer-centric framework for building applications that leverage large language models (LLMs), such as GPT-4. It focuses on enabling developers to build complex workflows and pipelines around LLMs. Key features include:
#
# 1. **Flexibility for Developers**:
#    - LangChain allows developers to create custom workflows, chain multiple LLM interactions, and incorporate external data sources.
#    - It supports integration with different LLM providers, including OpenAI, Hugging Face, and Anthropic.
#
# 2. **Tool Integration**:
#    - LangChain includes tools for connecting LLMs to external APIs, databases, and search engines, enabling dynamic and real-time applications.
#
# 3. **Rapid Prototyping**:
#    - It is ideal for experimentation and prototyping, as developers can quickly chain together various components to test new ideas.
#
# 4. **Open Source**:
#    - LangChain is open source, making it accessible for developers and startups. However, it requires developers to manage hosting, scaling, and infrastructure independently.
#
# ### **Why Enterprises Choose Azure for Production Systems**
# Enterprises often prefer Azure AI solutions over frameworks like LangChain for production systems due to the following reasons:
#
# 1. **Enterprise-Grade Security**:
#    - Azure provides comprehensive security measures, including built-in threat detection, data encryption, and identity and access management. This is critical for enterprises handling sensitive data.
#
# 2. **Compliance Certifications**:
#    - Azure meets stringent regulatory requirements, making it suitable for industries with strict compliance needs (e.g., healthcare, finance, government).
#
# 3. **Global Presence and Scalability**:
#    - Azure’s global infrastructure supports scalable deployments and ensures low latency for users worldwide, which is crucial for production systems.
#
# 4. **Managed Services Reduce Complexity**:
#    - Azure’s managed services, such as Azure OpenAI Service and Azure Machine Learning, simplify operations, allowing enterprises to focus on innovation rather than infrastructure management.
#
# 5. **Support and SLAs**:
#    - Azure provides enterprise-grade support and service-level agreements (SLAs), ensuring reliability and performance that align with business requirements.
#
# 6. **Integration Across the Stack**:
#    - Azure’s ecosystem enables seamless integration with other enterprise systems and tools, creating unified workflows and maximizing the value of AI deployments.
#
# 7. **Cost Optimization for Large-Scale Operations**:
#    - Azure offers flexible pricing models and tools for cost management, making it more economical for large-scale, long-term deployments compared to bespoke solutions requiring custom infrastructure.
#
# ### **Summary**
# LangChain is an excellent choice for developers and startups working on prototypes or exploratory projects, as it provides flexibility and open-source accessibility. However, enterprises prioritize factors like security, compliance, scalability, reliability, and managed services, which Azure excels at. For production systems, especially those requiring high performance, enterprise-grade support, and seamless integration across tools and workflows, Azure AI solutions are the preferred choice.
#
# Azure Agent demonstration completed.
# Suitable for reasoning, technical explanation, and enterprise applications.
